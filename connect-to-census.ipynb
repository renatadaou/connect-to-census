# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# ## 👉 download your data
#
# You can write code here to download your dataset. Or if you already have it, just leave the URL in the comments and just load it into a pandas or R (or both) dataframe.

# %%
import pandas as pd

# %%
df = pd.read_csv('bilingual.csv')
df['School'].value_counts()
# Out:
# School
# 75K721    7
# 24Q013    5
# 15K094    4
# 31R022    4
# 07X025    4
#          ..
# 12X550    1
# 12X463    1
# 12X214    1
# 12X196    1
# 79Q950    1
# Name: count, Length: 376, dtype: int64

# %% [markdown]
# ## 👉 convert addresses --> lat/long
#
# See the [census-examples](https://github.com/data4news/census-examples) repository for examples. If you need help, try asking in the class slack channel. Chances are someone in the class is struggling with the same problem as you are so we might as well all learn together in the same slack channel!

# %%
add = pd.read_csv('locations.csv')
add
# Out:
#       fiscal_year system_code location_code  \
# 0            2020      15K001          K001
# 1            2020      17K002          K002
# 2            2020      13K003          K003
# 3            2020      75K004          K004
# 4            2020      16K005          K005
# ...           ...         ...           ...
# 2185         2020      84X729          X729
# 2186         2020      84X730          X730
# 2187         2020      75X754          X754
# 2188         2020      75X811          X811
# 2189         2020      75X811          X811
#
#                                 location_name          BEDS Managed_by_name  \
# 0                         P.S. 001 The Bergen  331500010001             DOE
# 1                Parkside Preparatory Academy  331700010002             DOE
# 2                P.S. 003 The Bedford Village  331300010003             DOE
# 3                                   P.S. K004  307500013004             DOE
# 4                  P.S. 005 Dr. Ronald McNair  331600010005             DOE
# ...                                       ...           ...             ...
# 2185             Readnet Bronx Charter School  320700860842         Charter
# 2186        Bronx Charter School for the Arts  320800860846         Charter
# 2187  J. M. Rapport School Career Development  307500012754             DOE
# 2188                                P.S. X811  307500012811             DOE
# 2189                                P.S. X811  307500012811             DOE
#
#      location_type_description    Location_Category_Description  \
# 0             General Academic                       Elementary
# 1             General Academic  Junior High-Intermediate-Middle
# 2             General Academic                       Elementary
# 3            Special Education                       Elementary
# 4             General Academic                       Elementary
# ...                        ...                              ...
# 2185          General Academic                       Elementary
# 2186          General Academic                       Elementary
# 2187         Special Education                      High school
# 2188         Special Education                 Secondary School
# 2189         Special Education                 Secondary School
#
#                   Grades_text              Grades_final_text  ...  \
# 0     PK,0K,01,02,03,04,05,SE           PK,0K,01,02,03,04,05  ...
# 1                 06,07,08,SE                       06,07,08  ...
# 2     PK,0K,01,02,03,04,05,SE           PK,0K,01,02,03,04,05  ...
# 3     PK,0K,01,02,03,04,05,SE  PK,0K,01,02,03,04,05,06,07,SE  ...
# 4     PK,0K,01,02,03,04,05,SE           PK,0K,01,02,03,04,05  ...
# ...                       ...                            ...  ...
# 2185                    01,02                            NaN  ...
# 2186  0K,01,02,03,04,05,06,07     0K,01,02,03,04,05,06,07,08  ...
# 2187           09,10,11,12,SE                 09,10,11,12,SE  ...
# 2188        08,09,10,11,12,SE           07,08,09,10,11,12,SE  ...
# 2189        08,09,10,11,12,SE           07,08,09,10,11,12,SE  ...
#
#       Administrative_District_Name community_school_sup_name  \
# 0     COMMUNITY SCHOOL DISTRICT 15               SKOP, ANITA
# 1     COMMUNITY SCHOOL DISTRICT 17           ELLIS, CLARENCE
# 2     COMMUNITY SCHOOL DISTRICT 13            SAMUELS, KAMAR
# 3       CITYWIDE SPECIAL EDUCATION        LOUISSAINT, KETLER
# 4     COMMUNITY SCHOOL DISTRICT 16           MARTIN, YOLANDA
# ...                            ...                       ...
# 2185     OFFICE OF CHARTER SCHOOLS                       NaN
# 2186     OFFICE OF CHARTER SCHOOLS                       NaN
# 2187    CITYWIDE SPECIAL EDUCATION        LOUISSAINT, KETLER
# 2188    CITYWIDE SPECIAL EDUCATION        LOUISSAINT, KETLER
# 2189    CITYWIDE SPECIAL EDUCATION        LOUISSAINT, KETLER
#
#                 Tier_3_Support_Location_Name Tier_3_Support_Leader_Name  \
# 0     NYCDOE Borough Office - Brooklyn North                        NaN
# 1     NYCDOE Borough Office - Brooklyn South        Mauriciere de Govia
# 2     NYCDOE Borough Office - Brooklyn North                        NaN
# 3                           D75 CITYWIDE BCO            Tillman Roberto
# 4     NYCDOE Borough Office - Brooklyn North                        NaN
# ...                                      ...                        ...
# 2185                                     NaN                        NaN
# 2186                                     NaN                        NaN
# 2187                        D75 CITYWIDE BCO            Tillman Roberto
# 2188                        D75 CITYWIDE BCO            Tillman Roberto
# 2189                        D75 CITYWIDE BCO            Tillman Roberto
#
#                Tier_2_Support_Location_Name  HighSchool_Network_Location_Code  \
# 0     School Support Team 5- Brooklyn North                               NaN
# 1     School Support Team 2- Brooklyn South                               NaN
# 2     School Support Team 3- Brooklyn North                               NaN
# 3                Children First Network 752                               NaN
# 4     School Support Team 4- Brooklyn North                               NaN
# ...                                     ...                               ...
# 2185                                    NaN                               NaN
# 2186                                    NaN                               NaN
# 2187             Children First Network 755                               NaN
# 2188             Children First Network 755                               NaN
# 2189             Children First Network 755                               NaN
#
#       HighSchool_Network_Name  HighSchool_Network_Superintendent  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
# ...                       ...                                ...
# 2185                      NaN                                NaN
# 2186                      NaN                                NaN
# 2187                      NaN                                NaN
# 2188                      NaN                                NaN
# 2189                      NaN                                NaN
#
#       Community_district 1  Police_precinct
# 0                    307.0             72.0
# 1                    309.0             71.0
# 2                    303.0             79.0
# 3                    305.0             75.0
# 4                    303.0             81.0
# ...                    ...              ...
# 2185                 201.0             40.0
# 2186                 202.0             41.0
# 2187                 201.0             40.0
# 2188                 203.0             42.0
# 2189                 203.0             42.0
#
# [2190 rows x 41 columns]

# %%
# merge df and add where df key is 'School' and add key is 'system_code'

df_merge = pd.merge(df, add, left_on='School', right_on='system_code', how='left')
df_merge
# Out:
#        Borough Borough/Citywide Office (B/CO)  District  School  \
# 0    Manhattan                      Manhattan         1  01M020
# 1    Manhattan                      Manhattan         1  01M020
# 2    Manhattan                      Manhattan         1  01M184
# 3    Manhattan                      Manhattan         1  01M184
# 4    Manhattan                      Manhattan         1  01M188
# ..         ...                            ...       ...     ...
# 551      Bronx                    District 75        75  75X811
# 552      Bronx                    District 75        75  75X811
# 553      Bronx                    District 75        75  75X811
# 554  Manhattan                         ACCESS        79  79M973
# 555     Queens                         ACCESS        79  79Q950
#
#                     School Name   School Category  \
# 0          P.S. 020 Anna Silver        Elementary
# 1          P.S. 020 Anna Silver        Elementary
# 2          P.S. 184m Shuang Wen               K-8
# 3          P.S. 184m Shuang Wen               K-8
# 4    P.S. 188 The Island School               K-8
# ..                          ...               ...
# 551                   P.S. X811  Secondary School
# 552                   P.S. X811  Secondary School
# 553                   P.S. X811  Secondary School
# 554             Restart Academy          Ungraded
# 555      Pathways to Graduation       High school
#
#                               Program Language Language (Translated)  \
# 0                       Dual Language  Chinese                    中文
# 1                       Dual Language  Spanish               Español
# 2                       Dual Language  Chinese                    中文
# 3                       Dual Language  Chinese                    中文
# 4                       Dual Language  Spanish               Español
# ..                                ...      ...                   ...
# 551  Transitional Bilingual Education  Spanish               Español
# 552  Transitional Bilingual Education  Spanish               Español
# 553  Transitional Bilingual Education  Spanish               Español
# 554  Transitional Bilingual Education  Spanish               Español
# 555  Transitional Bilingual Education  Spanish               Español
#
#     General/Special Education  ...  Administrative_District_Name  \
# 0           General Education  ...  COMMUNITY SCHOOL DISTRICT 01
# 1           General Education  ...  COMMUNITY SCHOOL DISTRICT 01
# 2           General Education  ...  COMMUNITY SCHOOL DISTRICT 01
# 3           Special Education  ...  COMMUNITY SCHOOL DISTRICT 01
# 4           General Education  ...  COMMUNITY SCHOOL DISTRICT 01
# ..                        ...  ...                           ...
# 551         Special Education  ...    CITYWIDE SPECIAL EDUCATION
# 552         Special Education  ...    CITYWIDE SPECIAL EDUCATION
# 553         Special Education  ...    CITYWIDE SPECIAL EDUCATION
# 554         General Education  ...                           NaN
# 555         General Education  ...                           NaN
#
#      community_school_sup_name       Tier_3_Support_Location_Name  \
# 0                  CHAN, CARRY  NYCDOE Borough Office - Manhattan
# 1                  CHAN, CARRY  NYCDOE Borough Office - Manhattan
# 2                  CHAN, CARRY  NYCDOE Borough Office - Manhattan
# 3                  CHAN, CARRY  NYCDOE Borough Office - Manhattan
# 4                  CHAN, CARRY  NYCDOE Borough Office - Manhattan
# ..                         ...                                ...
# 551         LOUISSAINT, KETLER                   D75 CITYWIDE BCO
# 552         LOUISSAINT, KETLER                   D75 CITYWIDE BCO
# 553         LOUISSAINT, KETLER                   D75 CITYWIDE BCO
# 554                        NaN                                NaN
# 555                        NaN                                NaN
#
#     Tier_3_Support_Leader_Name      Tier_2_Support_Location_Name  \
# 0                    CHU, YUET  School Support Team 3- Manhattan
# 1                    CHU, YUET  School Support Team 3- Manhattan
# 2                    CHU, YUET  School Support Team 3- Manhattan
# 3                    CHU, YUET  School Support Team 3- Manhattan
# 4                    CHU, YUET  School Support Team 3- Manhattan
# ..                         ...                               ...
# 551            Tillman Roberto        Children First Network 755
# 552            Tillman Roberto        Children First Network 755
# 553            Tillman Roberto        Children First Network 755
# 554                        NaN                               NaN
# 555                        NaN                               NaN
#
#      HighSchool_Network_Location_Code HighSchool_Network_Name  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
# ..                                ...                     ...
# 551                               NaN                     NaN
# 552                               NaN                     NaN
# 553                               NaN                     NaN
# 554                               NaN                     NaN
# 555                               NaN                     NaN
#
#     HighSchool_Network_Superintendent Community_district 1 Police_precinct
# 0                                 NaN                103.0             7.0
# 1                                 NaN                103.0             7.0
# 2                                 NaN                103.0             7.0
# 3                                 NaN                103.0             7.0
# 4                                 NaN                103.0             9.0
# ..                                ...                  ...             ...
# 551                               NaN                203.0            42.0
# 552                               NaN                203.0            42.0
# 553                               NaN                203.0            42.0
# 554                               NaN                  NaN             NaN
# 555                               NaN                  NaN             NaN
#
# [556 rows x 52 columns]

# %%
df_merge.columns
# Out:
# Index(['Borough', 'Borough/Citywide Office (B/CO)', 'District', 'School',
#        'School Name', 'School Category', 'Program', 'Language',
#        'Language (Translated)', 'General/Special Education',
#        'Special Education Model', 'fiscal_year', 'system_code',
#        'location_code', 'location_name', 'BEDS', 'Managed_by_name',
#        'location_type_description', 'Location_Category_Description',
#        'Grades_text', 'Grades_final_text', 'open_date', 'Status_descriptions',
#        'Primary_building_code', 'primary_address_line_1', 'State_code',
#        'X_COORDINATE', 'Y_COORDINATE', 'LONGITUDE', 'LATITUDE',
#        'Community_district', 'Council-district', 'Census_tract',
#        'Borough_block_lot', 'NTA', 'NTA_Name', 'Principal_Name',
#        'Principal_title', 'Principal_phone_number', 'fax_number',
#        'Geographical_District_code', 'Administrative_District_Code',
#        'Administrative_District_Name', 'community_school_sup_name',
#        'Tier_3_Support_Location_Name', 'Tier_3_Support_Leader_Name',
#        'Tier_2_Support_Location_Name', 'HighSchool_Network_Location_Code',
#        'HighSchool_Network_Name', 'HighSchool_Network_Superintendent',
#        'Community_district 1', 'Police_precinct'],
#       dtype='object')

# %% [markdown]
# ## 👉 convert lat/long to census geography codes
#
# (like 'GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK', etc...)
#
# Same note as above, see [census-examples](https://github.com/data4news/census-examples) repository for examples or ask in the class slack channel if stuck.

# %%
import glob
import json
import requests
import pandas as pd
from pprint import pprint

# %%
# datamade's Census package
from census import Census

# %%
c = Census("2b439405843d7c5b73d408bf38e100d4bb36ea87")

# %%
dem = pd.read_csv('demographics.csv')
dem
# Out:
#          DBN                        School Name     Year  Total Enrollment  \
# 0     01M015          P.S. 015 Roberto Clemente  2016-17               178
# 1     01M015          P.S. 015 Roberto Clemente  2017-18               190
# 2     01M015          P.S. 015 Roberto Clemente  2018-19               174
# 3     01M015          P.S. 015 Roberto Clemente  2019-20               190
# 4     01M015          P.S. 015 Roberto Clemente  2020-21               193
# ...      ...                                ...      ...               ...
# 9164  84X730  Bronx Charter School for the Arts  2016-17               320
# 9165  84X730  Bronx Charter School for the Arts  2017-18               314
# 9166  84X730  Bronx Charter School for the Arts  2018-19               430
# 9167  84X730  Bronx Charter School for the Arts  2019-20               523
# 9168  84X730  Bronx Charter School for the Arts  2020-21               626
#
#       Grade 3K+PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# 0                                    17       28       33       27       31
# 1                                    17       28       32       33       23
# 2                                    13       20       33       30       30
# 3                                    14       29       28       38       33
# 4                                    17       29       29       27       30
# ...                                 ...      ...      ...      ...      ...
# 9164                                  0       53       53       55       52
# 9165                                  0       50       51       54       51
# 9166                                  0       49       54       49       54
# 9167                                  0       51       50       53       52
# 9168                                  0       38       52       53       55
#
#       Grade 4  ...   % White  # Missing Race/Ethnicity Data  \
# 0          24  ...  0.022000                              0
# 1          31  ...  0.032000                              0
# 2          20  ...  0.034000                              0
# 3          29  ...  0.047000                              0
# 4          32  ...  0.057000                              0
# ...       ...  ...       ...                            ...
# 9164       53  ...  0.009375                              0
# 9165       52  ...  0.003185                              0
# 9166       51  ...  0.006977                              0
# 9167       55  ...  0.009560                              0
# 9168       55  ...  0.006390                              1
#
#       % Missing Race/Ethnicity Data  # Students with Disabilities  \
# 0                          0.000000                            51
# 1                          0.000000                            49
# 2                          0.000000                            39
# 3                          0.000000                            46
# 4                          0.000000                            43
# ...                             ...                           ...
# 9164                       0.000000                            67
# 9165                       0.000000                            68
# 9166                       0.000000                           103
# 9167                       0.000000                           117
# 9168                       0.001597                           153
#
#       % Students with Disabilities  # English Language Learners  \
# 0                         0.287000                           12
# 1                         0.258000                            8
# 2                         0.224000                            8
# 3                         0.242000                           17
# 4                         0.223000                           21
# ...                            ...                          ...
# 9164                      0.209375                           51
# 9165                      0.216561                           57
# 9166                      0.239535                           71
# 9167                      0.223709                           69
# 9168                      0.244409                           78
#
#       % English Language Learners  # Poverty  % Poverty  Economic Need Index
# 0                           0.067        152      85.4%                88.2%
# 1                           0.042        161      84.7%                89.0%
# 2                           0.046        147      84.5%                88.8%
# 3                           0.089        155      81.6%                86.7%
# 4                           0.109        158      81.9%                85.6%
# ...                           ...        ...        ...                  ...
# 9164                        0.159        235      73.4%                84.0%
# 9165                        0.182        258      82.2%                89.1%
# 9166                        0.165        363      84.4%                88.8%
# 9167                        0.132        453      86.6%                89.2%
# 9168                        0.125        541      86.4%                88.2%
#
# [9169 rows x 43 columns]

# %%
df_merge2 = pd.merge(df_merge, dem, left_on='School', right_on='DBN', how='left')
df_merge2
# Out:
#         Borough Borough/Citywide Office (B/CO)  District  School  \
# 0     Manhattan                      Manhattan         1  01M020
# 1     Manhattan                      Manhattan         1  01M020
# 2     Manhattan                      Manhattan         1  01M020
# 3     Manhattan                      Manhattan         1  01M020
# 4     Manhattan                      Manhattan         1  01M020
# ...         ...                            ...       ...     ...
# 2757     Queens                         ACCESS        79  79Q950
# 2758     Queens                         ACCESS        79  79Q950
# 2759     Queens                         ACCESS        79  79Q950
# 2760     Queens                         ACCESS        79  79Q950
# 2761     Queens                         ACCESS        79  79Q950
#
#                School Name_x School Category  \
# 0       P.S. 020 Anna Silver      Elementary
# 1       P.S. 020 Anna Silver      Elementary
# 2       P.S. 020 Anna Silver      Elementary
# 3       P.S. 020 Anna Silver      Elementary
# 4       P.S. 020 Anna Silver      Elementary
# ...                      ...             ...
# 2757  Pathways to Graduation     High school
# 2758  Pathways to Graduation     High school
# 2759  Pathways to Graduation     High school
# 2760  Pathways to Graduation     High school
# 2761  Pathways to Graduation     High school
#
#                                Program Language Language (Translated)  \
# 0                        Dual Language  Chinese                    中文
# 1                        Dual Language  Chinese                    中文
# 2                        Dual Language  Chinese                    中文
# 3                        Dual Language  Chinese                    中文
# 4                        Dual Language  Chinese                    中文
# ...                                ...      ...                   ...
# 2757  Transitional Bilingual Education  Spanish               Español
# 2758  Transitional Bilingual Education  Spanish               Español
# 2759  Transitional Bilingual Education  Spanish               Español
# 2760  Transitional Bilingual Education  Spanish               Español
# 2761  Transitional Bilingual Education  Spanish               Español
#
#      General/Special Education  ... % White  # Missing Race/Ethnicity Data  \
# 0            General Education  ...   0.050                              0
# 1            General Education  ...   0.032                              1
# 2            General Education  ...   0.046                              1
# 3            General Education  ...   0.067                              1
# 4            General Education  ...   0.073                              1
# ...                        ...  ...     ...                            ...
# 2757         General Education  ...   0.054                              0
# 2758         General Education  ...   0.050                              0
# 2759         General Education  ...   0.052                              0
# 2760         General Education  ...   0.048                              0
# 2761         General Education  ...   0.059                              0
#
#      % Missing Race/Ethnicity Data # Students with Disabilities  \
# 0                            0.000                          116
# 1                            0.002                          118
# 2                            0.002                          117
# 3                            0.002                          106
# 4                            0.002                           90
# ...                            ...                          ...
# 2757                         0.000                          410
# 2758                         0.000                          400
# 2759                         0.000                          469
# 2760                         0.000                          449
# 2761                         0.000                          537
#
#      % Students with Disabilities  # English Language Learners  \
# 0                           0.215                           93
# 1                           0.237                           86
# 2                           0.243                           63
# 3                           0.228                           61
# 4                           0.218                           49
# ...                           ...                          ...
# 2757                        0.107                          542
# 2758                        0.113                          473
# 2759                        0.132                          547
# 2760                        0.128                          565
# 2761                        0.160                          539
#
#      % English Language Learners # Poverty % Poverty Economic Need Index
# 0                          0.172       315     58.3%               67.7%
# 1                          0.173       366     73.6%               80.0%
# 2                          0.131       326     67.8%               75.4%
# 3                          0.131       354     76.3%               78.4%
# 4                          0.119       292     70.9%               76.2%
# ...                          ...       ...       ...                 ...
# 2757                       0.141      1569     40.9%               72.0%
# 2758                       0.134      2607     73.9%               88.3%
# 2759                       0.154      2597     73.1%               87.8%
# 2760                       0.161      2629     74.9%               91.2%
# 2761                       0.161      2634     78.6%               90.6%
#
# [2762 rows x 95 columns]

# %%
df_merge2['Census_tract']
# Out:
# 0       3001.0
# 1       3001.0
# 2       3001.0
# 3       3001.0
# 4       3001.0
#          ...
# 2757       NaN
# 2758       NaN
# 2759       NaN
# 2760       NaN
# 2761       NaN
# Name: Census_tract, Length: 2762, dtype: float64

# %%
df_merge2['Census_tract'].value_counts()
# Out:
# Census_tract
# 40900.0    80
# 25100.0    45
# 27700.0    45
# 48500.0    40
# 30800.0    40
#            ..
# 27400.0     5
# 22702.0     5
# 18400.0     5
# 46201.0     3
# 1003.0      2
# Name: count, Length: 262, dtype: int64

# %% [markdown]
# ## 👉 Output Data
#
# Output your dataframe containing your data and the Census connector codes (like tract, block, etc...).

# %%
df_merge2
# Out:
#         Borough Borough/Citywide Office (B/CO)  District  School  \
# 0     Manhattan                      Manhattan         1  01M020
# 1     Manhattan                      Manhattan         1  01M020
# 2     Manhattan                      Manhattan         1  01M020
# 3     Manhattan                      Manhattan         1  01M020
# 4     Manhattan                      Manhattan         1  01M020
# ...         ...                            ...       ...     ...
# 2757     Queens                         ACCESS        79  79Q950
# 2758     Queens                         ACCESS        79  79Q950
# 2759     Queens                         ACCESS        79  79Q950
# 2760     Queens                         ACCESS        79  79Q950
# 2761     Queens                         ACCESS        79  79Q950
#
#                School Name_x School Category  \
# 0       P.S. 020 Anna Silver      Elementary
# 1       P.S. 020 Anna Silver      Elementary
# 2       P.S. 020 Anna Silver      Elementary
# 3       P.S. 020 Anna Silver      Elementary
# 4       P.S. 020 Anna Silver      Elementary
# ...                      ...             ...
# 2757  Pathways to Graduation     High school
# 2758  Pathways to Graduation     High school
# 2759  Pathways to Graduation     High school
# 2760  Pathways to Graduation     High school
# 2761  Pathways to Graduation     High school
#
#                                Program Language Language (Translated)  \
# 0                        Dual Language  Chinese                    中文
# 1                        Dual Language  Chinese                    中文
# 2                        Dual Language  Chinese                    中文
# 3                        Dual Language  Chinese                    中文
# 4                        Dual Language  Chinese                    中文
# ...                                ...      ...                   ...
# 2757  Transitional Bilingual Education  Spanish               Español
# 2758  Transitional Bilingual Education  Spanish               Español
# 2759  Transitional Bilingual Education  Spanish               Español
# 2760  Transitional Bilingual Education  Spanish               Español
# 2761  Transitional Bilingual Education  Spanish               Español
#
#      General/Special Education  ... % White  # Missing Race/Ethnicity Data  \
# 0            General Education  ...   0.050                              0
# 1            General Education  ...   0.032                              1
# 2            General Education  ...   0.046                              1
# 3            General Education  ...   0.067                              1
# 4            General Education  ...   0.073                              1
# ...                        ...  ...     ...                            ...
# 2757         General Education  ...   0.054                              0
# 2758         General Education  ...   0.050                              0
# 2759         General Education  ...   0.052                              0
# 2760         General Education  ...   0.048                              0
# 2761         General Education  ...   0.059                              0
#
#      % Missing Race/Ethnicity Data # Students with Disabilities  \
# 0                            0.000                          116
# 1                            0.002                          118
# 2                            0.002                          117
# 3                            0.002                          106
# 4                            0.002                           90
# ...                            ...                          ...
# 2757                         0.000                          410
# 2758                         0.000                          400
# 2759                         0.000                          469
# 2760                         0.000                          449
# 2761                         0.000                          537
#
#      % Students with Disabilities  # English Language Learners  \
# 0                           0.215                           93
# 1                           0.237                           86
# 2                           0.243                           63
# 3                           0.228                           61
# 4                           0.218                           49
# ...                           ...                          ...
# 2757                        0.107                          542
# 2758                        0.113                          473
# 2759                        0.132                          547
# 2760                        0.128                          565
# 2761                        0.160                          539
#
#      % English Language Learners # Poverty % Poverty Economic Need Index
# 0                          0.172       315     58.3%               67.7%
# 1                          0.173       366     73.6%               80.0%
# 2                          0.131       326     67.8%               75.4%
# 3                          0.131       354     76.3%               78.4%
# 4                          0.119       292     70.9%               76.2%
# ...                          ...       ...       ...                 ...
# 2757                       0.141      1569     40.9%               72.0%
# 2758                       0.134      2607     73.9%               88.3%
# 2759                       0.154      2597     73.1%               87.8%
# 2760                       0.161      2629     74.9%               91.2%
# 2761                       0.161      2634     78.6%               90.6%
#
# [2762 rows x 95 columns]

# %%
df_merge2.to_csv('output.csv', index=False)
